# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def plot_function(func, x_range=(0, 0.6), num_points=10000000):
    x_values = np.linspace(x_range[0], x_range[1], num_points)
    y_values = func(x_values)

    plt.plot(x_values, y_values)
    plt.xlabel('t, мс')
    plt.ylabel('u(t), В')
    # plt.title('Plot of the Function')
    plt.grid(True)
    plt.show()


def quadratic_function(x):
    return -0.9*math.e**(-100000*x*10**(-3))+1.7*math.e**(-20000*x*10**(-3))

plot_function(quadratic_function)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def plot_function(func, x_range=(0, 0.0001), num_points=10000000):
    x_values = np.linspace(x_range[0], x_range[1], num_points)
    y_values = func(x_values)

    plt.plot(x_values, y_values)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Plot of the Function')
    plt.grid(True)
    plt.show()


def quadratic_function(x):
    return (10**(19))*math.e**(-10000*x)+(10**(10))*math.e**(-25000*x)*math.cos(61441*x+(math.pi/2))

plot_function(quadratic_function)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 20
#      17 def quadratic_function(x):
#      18     return (10**(19))*math.e**(-10000*x)+(10**(10))*math.e**(-25000*x)*math.cos(61441*x+(math.pi/2))
# ---> 20 plot_function(quadratic_function)
#
# Cell In[51], line 7, in plot_function(func, x_range, num_points)
#       5 def plot_function(func, x_range=(0, 0.0001), num_points=10000000):
#       6     x_values = np.linspace(x_range[0], x_range[1], num_points)
# ----> 7     y_values = func(x_values)
#       9     plt.plot(x_values, y_values)
#      10     plt.xlabel('X')
#
# Cell In[51], line 18, in quadratic_function(x)
#      17 def quadratic_function(x):
# ---> 18     return (10**(19))*math.e**(-10000*x)+(10**(10))*math.e**(-25000*x)*math.cos(61441*x+(math.pi/2))
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def func(x, a, b, c):
    return a*math.e**(-10000*x*10**(-3)) + b*math.e**(-25000*x*10**(-3))*math.cos(61441*x*10**(-3)) + c*math.e**(-25000*x*10**(-3))*math.sin(61441*x*10**(-3))

x_values = np.linspace(0, 0.6, 1000)  # Задаем диапазон значений x

# Вычисляем значения функции для каждого x
a = 0.0
for i in range(1):
    a += 0.1
    y_values = [func(x, 0.605, 0.6, 0.105) for x in x_values]

# Строим график
    plt.plot(x_values, y_values)
plt.xlabel('t, мс')
plt.ylabel('u(t), В')
# plt.title('Plot of the Function')
plt.grid(True)
plt.show()
